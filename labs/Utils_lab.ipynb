# %%
import pandas as pd

dataset = pd.read_csv("data/clinical_annotation.csv", index_col=0)
print(dataset.head())
# print(dataset.isna().any())
# Out:
#      ID  LABEL GENDER        DOB  LYMPH_COUNT
# 0   P26      1      M  11/3/1933         11.2
# 1  P183      1      M  5/15/1942         12.8
# 2   P89      1      M  6/19/1935          9.6
# 3  P123      1      M  1/27/1931        122.6
# 4   P61      1      F   3/5/1931         11.6

# %%
import shutil

for idx, x in dataset[dataset.LABEL >= 0].iterrows():
    print(x.ID, x.LABEL)
    shutil.copytree(f"data/trainset/{x.ID}", f"data/trainset_sorted/label_{x.LABEL}/{x.ID}")
# Out:
# P26 1
# P183 1
# P89 1
# P123 1
# P61 1
# P112 1
# P63 0
# P184 1
# P23 1
# P100 1
# P11 1
# P111 1
# P28 1
# P192 1
# P35 1
# P27 1
# P113 1
# P33 1
# P17 1
# P126 1
# P199 1
# P176 1
# P46 1
# P44 0
# P137 0
# P13 1
# P74 1
# P134 1
# P128 1
# P0 1
# P202 1
# P157 1
# P42 1
# P161 1
# P163 1
# P159 0
# P38 1
# P190 1
# P12 1
# P115 1
# P122 1
# P116 1
# P144 1
# P15 1
# P154 1
# P48 1
# P187 1
# P200 0
# P99 1
# P150 1
# P53 1
# P191 1
# P79 1
# P169 0
# P19 1
# P121 1
# P90 1
# P37 1
# P171 1
# P174 1
# P117 1
# P141 1
# P140 0
# P85 1
# P59 1
# P51 1
# P168 1
# P31 1
# P21 1
# P1 1
# P97 1
# P67 1
# P107 1
# P54 0
# P181 1
# P94 1
# P30 1
# P142 1
# P109 1
# P129 0
# P47 1
# P91 1
# P2 1
# P22 1
# P62 1
# P88 1
# P66 1
# P83 1
# P76 1
# P118 1
# P65 1
# P180 1
# P179 0
# P147 1
# P189 1
# P173 0
# P104 1
# P41 0
# P166 0
# P80 0
# P193 1
# P194 0
# P164 0
# P6 0
# P45 0
# P155 0
# P182 0
# P55 1
# P177 0
# P124 1
# P165 1
# P201 1
# P110 0
# P105 0
# P125 0
# P136 1
# P102 1
# ...
